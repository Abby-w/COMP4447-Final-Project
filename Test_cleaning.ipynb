# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1 (1).csv')

# %%
df
# Out:
#                 Timestamp How old are you?  \
# 0      4/27/2021 11:02:10            25-34
# 1      4/27/2021 11:02:22            25-34
# 2      4/27/2021 11:02:38            25-34
# 3      4/27/2021 11:02:41            25-34
# 4      4/27/2021 11:02:42            25-34
# ...                   ...              ...
# 27676  2/19/2022 16:07:31            45-54
# 27677  2/19/2022 18:17:08            25-34
# 27678  2/19/2022 19:47:05            25-34
# 27679  2/21/2022 19:43:29            25-34
# 27680  2/22/2022 13:05:17            25-34
#
#                                     Industry  \
# 0               Education (Higher Education)
# 1                          Computing or Tech
# 2              Accounting, Banking & Finance
# 3                                 Nonprofits
# 4              Accounting, Banking & Finance
# ...                                      ...
# 27676               Property or Construction
# 27677                              Insurance
# 27678          Accounting, Banking & Finance
# 27679  Education (Early Childhood Education)
# 27680                    Political Campaigns
#
#                                       Job title  \
# 0            Research and Instruction Librarian
# 1      Change & Internal Communications Manager
# 2                          Marketing Specialist
# 3                               Program Manager
# 4                            Accounting Manager
# ...                                         ...
# 27676                   Senior Project Manager
# 27677                               Underwriter
# 27678     Vice Presidenti and Corporate Counsel
# 27679                 Quality Rating Specialist
# 27680              Congressional Field Director
#
#                          Additional context on job title Annual salary  \
# 0                                                    NaN        55,000
# 1                                                    NaN        54,600
# 2                                                    NaN        34,000
# 3                                                    NaN        62,000
# 4                                                    NaN        60,000
# ...                                                  ...           ...
# 27676                               Owner rep consultant        145000
# 27677                                                NaN         67000
# 27678                                (in-house attorney)        252000
# 27679  Program assessor to conduct quality assessment...         62400
# 27680                                                NaN         66000
#
#        Other monetary comp Currency Currency - other  \
# 0                      0.0      USD              NaN
# 1                   4000.0      GBP              NaN
# 2                      NaN      USD              NaN
# 3                   3000.0      USD              NaN
# 4                   7000.0      USD              NaN
# ...                    ...      ...              ...
# 27676              14500.0      USD              NaN
# 27677               6700.0      USD              NaN
# 27678              80000.0      USD              NaN
# 27679                  NaN      USD              NaN
# 27680               5500.0      USD              NaN
#
#                             Additional context on income         Country  \
# 0                                                    NaN   United States
# 1                                                    NaN  United Kingdom
# 2                                                    NaN              US
# 3                                                    NaN             USA
# 4                                                    NaN              US
# ...                                                  ...             ...
# 27676  Guaranteed 10% bonus if our department meets t...             USA
# 27677                                                NaN             USA
# 27678                     I also receive an equity grant              US
# 27679                                                NaN   United States
# 27680  Paid as $5,500 monthly, with a month's salary ...   United States
#
#                 State            City  \
# 0       Massachusetts          Boston
# 1                 NaN       Cambridge
# 2           Tennessee     Chattanooga
# 3           Wisconsin       Milwaukee
# 4      South Carolina      Greenville
# ...               ...             ...
# 27676      California   San Francisco
# 27677         Florida           Tampa
# 27678    Pennsylvania    Philadelphia
# 27679      California       San Diego
# 27680        Virginia  Virginia Beach
#
#       Overall years of professional experience Years of experience in field  \
# 0                                    5-7 years                    5-7 years
# 1                                 8 - 10 years                    5-7 years
# 2                                  2 - 4 years                  2 - 4 years
# 3                                 8 - 10 years                    5-7 years
# 4                                 8 - 10 years                    5-7 years
# ...                                        ...                          ...
# 27676                            11 - 20 years                11 - 20 years
# 27677                             8 - 10 years                11 - 20 years
# 27678                            11 - 20 years                11 - 20 years
# 27679                            11 - 20 years                 8 - 10 years
# 27680                                5-7 years                    5-7 years
#
#       Highest level of education completed      Gender  \
# 0                          Master's degree       Woman
# 1                           College degree  Non-binary
# 2                           College degree       Woman
# 3                           College degree       Woman
# 4                           College degree       Woman
# ...                                    ...         ...
# 27676                       College degree       Woman
# 27677                      Master's degree       Woman
# 27678   Professional degree (MD, JD, etc.)       Woman
# 27679                       College degree       Woman
# 27680                       College degree       Woman
#
#                           Race
# 0                        White
# 1                        White
# 2                        White
# 3                        White
# 4                        White
# ...                        ...
# 27676  Asian or Asian American
# 27677                    White
# 27678                    White
# 27679  Asian or Asian American
# 27680                    White
#
# [27681 rows x 18 columns]

# %%
df.dtypes
# Out:
# Timestamp                                    object
# How old are you?                             object
# Industry                                     object
# Job title                                    object
# Additional context on job title              object
# Annual salary                                object
# Other monetary comp                         float64
# Currency                                     object
# Currency - other                             object
# Additional context on income                 object
# Country                                      object
# State                                        object
# City                                         object
# Overall years of professional experience     object
# Years of experience in field                 object
# Highest level of education completed         object
# Gender                                       object
# Race                                         object
# dtype: object

# %%
df.nunique()
# Out:
# Timestamp                                   24899
# How old are you?                                7
# Industry                                     1199
# Job title                                   14168
# Additional context on job title              6909
# Annual salary                                4246
# Other monetary comp                           836
# Currency                                       11
# Currency - other                              111
# Additional context on income                 2951
# Country                                       365
# State                                         129
# City                                         4758
# Overall years of professional experience        8
# Years of experience in field                    8
# Highest level of education completed            6
# Gender                                          5
# Race                                           48
# dtype: int64

# %% [markdown]
# To do:
# * decide if we want to only look in the US
#
# x 1) remove timestamp <br>
# x 2) set How old are you? to categorical<br>
# 3) refine/group industry<br>
# 4) refine/group job title<br>
# x 5) remove Additional context on job title <br>
# x 6) combine Annual salary with Other monetary comp ? and convert to float<br>
# 7) add Currency -other information to currency and then remove and make Currency categorical<br>
# x 8) remove Additional context on income <br>
# 9) refine country and make categorical<br>
# 10) clean state??<br>
# 11) clean City?<br>
# 12) make Overall years of professional experience categroical<br>
# 13) make Years of experience in field categorical<br>
# 14) refine Highest level of education completed and make categorical<br>
# x 15) make gender categorical<br>
# x 16) make race categorical<br>

# %%
df=df.drop(['Timestamp', 'Additional context on income', 'Additional context on job title'], axis=1)

# %%
df['How old are you?']=df['How old are you?'].astype('category')
df['Gender']=df['Gender'].astype('category')
df['Race']=df['Race'].astype('category')

# %%
df['Annual salary']=df['Annual salary'].astype('str')
df['Annual salary']=df['Annual salary'].str.replace(',','')
df['Annual salary']=df['Annual salary'].astype('float64')
df['Annual salary']=df['Annual salary'].fillna(0)
df['Other monetary comp']=df['Other monetary comp'].fillna(0)
df["Total Salary"] = df['Annual salary'] + df['Other monetary comp']
df=df.drop(['Annual salary', 'Other monetary comp'], axis=1)

# %%
df
# Out:
#       How old are you?                               Industry  \
# 0                25-34           Education (Higher Education)
# 1                25-34                      Computing or Tech
# 2                25-34          Accounting, Banking & Finance
# 3                25-34                             Nonprofits
# 4                25-34          Accounting, Banking & Finance
# ...                ...                                    ...
# 27676            45-54               Property or Construction
# 27677            25-34                              Insurance
# 27678            25-34          Accounting, Banking & Finance
# 27679            25-34  Education (Early Childhood Education)
# 27680            25-34                    Political Campaigns
#
#                                       Job title Currency Currency - other  \
# 0            Research and Instruction Librarian      USD              NaN
# 1      Change & Internal Communications Manager      GBP              NaN
# 2                          Marketing Specialist      USD              NaN
# 3                               Program Manager      USD              NaN
# 4                            Accounting Manager      USD              NaN
# ...                                         ...      ...              ...
# 27676                   Senior Project Manager       USD              NaN
# 27677                               Underwriter      USD              NaN
# 27678     Vice Presidenti and Corporate Counsel      USD              NaN
# 27679                 Quality Rating Specialist      USD              NaN
# 27680              Congressional Field Director      USD              NaN
#
#               Country           State            City  \
# 0       United States   Massachusetts          Boston
# 1      United Kingdom             NaN       Cambridge
# 2                  US       Tennessee     Chattanooga
# 3                 USA       Wisconsin       Milwaukee
# 4                  US  South Carolina      Greenville
# ...               ...             ...             ...
# 27676             USA      California   San Francisco
# 27677             USA         Florida           Tampa
# 27678              US    Pennsylvania    Philadelphia
# 27679   United States      California       San Diego
# 27680   United States        Virginia  Virginia Beach
#
#       Overall years of professional experience Years of experience in field  \
# 0                                    5-7 years                    5-7 years
# 1                                 8 - 10 years                    5-7 years
# 2                                  2 - 4 years                  2 - 4 years
# 3                                 8 - 10 years                    5-7 years
# 4                                 8 - 10 years                    5-7 years
# ...                                        ...                          ...
# 27676                            11 - 20 years                11 - 20 years
# 27677                             8 - 10 years                11 - 20 years
# 27678                            11 - 20 years                11 - 20 years
# 27679                            11 - 20 years                 8 - 10 years
# 27680                                5-7 years                    5-7 years
#
#       Highest level of education completed      Gender  \
# 0                          Master's degree       Woman
# 1                           College degree  Non-binary
# 2                           College degree       Woman
# 3                           College degree       Woman
# 4                           College degree       Woman
# ...                                    ...         ...
# 27676                       College degree       Woman
# 27677                      Master's degree       Woman
# 27678   Professional degree (MD, JD, etc.)       Woman
# 27679                       College degree       Woman
# 27680                       College degree       Woman
#
#                           Race  Total Salary
# 0                        White       55000.0
# 1                        White       58600.0
# 2                        White       34000.0
# 3                        White       65000.0
# 4                        White       67000.0
# ...                        ...           ...
# 27676  Asian or Asian American      159500.0
# 27677                    White       73700.0
# 27678                    White      332000.0
# 27679  Asian or Asian American       62400.0
# 27680                    White       71500.0
#
# [27681 rows x 14 columns]
